# %%
import pandas as pd
import csv

df = pd.read_csv('haunted_places.csv', index_col=False)
df
# Out:
#                 city        country  \
# 0                Ada  United States
# 1            Addison  United States
# 2             Adrian  United States
# 3             Adrian  United States
# 4             Albion  United States
# ...              ...            ...
# 10987    Westminster  United States
# 10988    Westminster  United States
# 10989    Wheat Ridge  United States
# 10990    Wheat Ridge  United States
# 10991  Woodland Park  United States
#
#                                              description  \
# 0      Ada witch - Sometimes you can see a misty blue...
# 1      A little girl was killed suddenly while waitin...
# 2      If you take Gorman Rd. west towards Sand Creek...
# 3      In the 1970's, one room, room 211, in the old ...
# 4      Kappa Delta Sorority - The Kappa Delta Sororit...
# ...                                                  ...
# 10987  at 12 midnight you can see a lady with two lit...
# 10988  Is haunted by the victims of a murder that hap...
# ...

# %%
df.dropna(how='any', axis=0, inplace=True)
df
# Out:
#                 city        country  \
# 0                Ada  United States
# 1            Addison  United States
# 2             Adrian  United States
# 3             Adrian  United States
# 4             Albion  United States
# ...              ...            ...
# 10987    Westminster  United States
# 10988    Westminster  United States
# 10989    Wheat Ridge  United States
# 10990    Wheat Ridge  United States
# 10991  Woodland Park  United States
#
#                                              description  \
# 0      Ada witch - Sometimes you can see a misty blue...
# 1      A little girl was killed suddenly while waitin...
# 2      If you take Gorman Rd. west towards Sand Creek...
# 3      In the 1970's, one room, room 211, in the old ...
# 4      Kappa Delta Sorority - The Kappa Delta Sororit...
# ...                                                  ...
# 10987  at 12 midnight you can see a lady with two lit...
# 10988  Is haunted by the victims of a murder that hap...
# ...

# %%
df.drop(["city_longitude", "city_latitude"], axis=1, inplace=True)

# %%
# df['description'].map(lambda x: x.replace('"', ''))
# df.replace('"','', regex=True, inplace=True)
# df
df_reset = df.set_index("city")
df_reset
# Out:
#                      country  \
# city
# Ada            United States
# Addison        United States
# Adrian         United States
# Adrian         United States
# Albion         United States
# ...                      ...
# Westminster    United States
# Westminster    United States
# Wheat Ridge    United States
# Wheat Ridge    United States
# Woodland Park  United States
#
#                                                      description  \
# city
# Ada            Ada witch - Sometimes you can see a misty blue...
# Addison        A little girl was killed suddenly while waitin...
# Adrian         If you take Gorman Rd. west towards Sand Creek...
# Adrian         In the 1970's, one room, room 211, in the old ...
# Albion         Kappa Delta Sorority - The Kappa Delta Sororit...
# ...                                                          ...
# Westminster    at 12 midnight you can see a lady with two lit...
# Westminster    Is haunted by the victims of a murder that hap...
# ...

# %%
df_reset.to_csv('cleandf.csv')
