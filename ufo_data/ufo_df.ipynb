# %%
import pandas as pd
import csv

# %%
ufo_df = pd.read_csv('UFO_data.csv', index_col=False,low_memory=False)
ufo_df
# Out:
#                                              Description     Shape  \
# 0      Viewed some red lights in the sky appearing to...     light
# 1      Look like 1 or 3 crafts from North traveling s...  triangle
# 2      One red light moving switly west to east, beco...  triangle
# 3      I'm familiar with all the fakery and UFO sight...   unknown
# 4      I was driving up lakes mead towards the lake a...      oval
# ...                                                  ...       ...
# 93529  group of 7 white flashing and disappearing fly...    sphere
# 93530  Bright light at high altitude, looked like a l...     light
# 93531  This object was disc shaped and parked frozen ...      disk
# 93532  Cloaked light disc pretends to be a cloud form...      disk
# 93533  6 red flashing lights in the sky over North GA...     light
#
#             Duration        City State        Date      Time   Latitude  \
# 0          2 minutes     Visalia    CA  12/15/2021  21:45:00  36.356650
# ...
