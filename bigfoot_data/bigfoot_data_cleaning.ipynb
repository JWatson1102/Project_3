# %%
import pandas as pd

# %%
bigfoot_df = pd.read_csv("bfro_reports_geocoded.csv")
bigfoot_df
# Out:
#                                                observed  \
# 0     I was canoeing on the Sipsey river in Alabama....
# 1     Ed L. was salmon fishing with a companion in P...
# 2     While attending U.R.I in the Fall of 1974,I wo...
# 3     Hello, My name is Doug and though I am very re...
# 4     It was May 1984. Two friends and I were up in ...
# ...                                                 ...
# 5016  while camping protecting other equipment befor...
# 5017  I was on my way to work on a Saturday morning ...
# 5018  On the twenty sixth and again on the twenty se...
# 5019  I was hunting on me and my neighbor's property...
# 5020  I was riding with a friend in the summer of 19...
#
#                                        location_details  \
# 0                                                   NaN
# 1                     East side of Prince William Sound
# 2                Great swamp area, Narragansett Indians
# 3     I would rather not have exact location (listin...
# ...

# %%
bigfoot_df.columns
# Out:
# Index(['observed', 'location_details', 'county', 'state', 'season', 'title',
#        'latitude', 'longitude', 'date', 'number', 'classification', 'geohash',
#        'temperature_high', 'temperature_mid', 'temperature_low', 'dew_point',
#        'humidity', 'cloud_cover', 'moon_phase', 'precip_intensity',
#        'precip_probability', 'precip_type', 'pressure', 'summary', 'uv_index',
#        'visibility', 'wind_bearing', 'wind_speed'],
#       dtype='object')

# %%
simplified_df = bigfoot_df[['observed','county','state','latitude', 'longitude','date',]]
simplified_df
# Out:
#                                                observed  \
# 0     I was canoeing on the Sipsey river in Alabama....
# 1     Ed L. was salmon fishing with a companion in P...
# 2     While attending U.R.I in the Fall of 1974,I wo...
# 3     Hello, My name is Doug and though I am very re...
# 4     It was May 1984. Two friends and I were up in ...
# ...                                                 ...
# 5016  while camping protecting other equipment befor...
# 5017  I was on my way to work on a Saturday morning ...
# 5018  On the twenty sixth and again on the twenty se...
# 5019  I was hunting on me and my neighbor's property...
# 5020  I was riding with a friend in the summer of 19...
#
#                               county         state  latitude  longitude  \
# 0                     Winston County       Alabama       NaN        NaN
# 1     Valdez-Chitina-Whittier County        Alaska       NaN        NaN
# 2                  Washington County  Rhode Island     41.45      -71.5
# ...

# %%
simplified_df.dropna(how='any', axis=0, inplace=True)
simplified_df
# Out:
# C:\Users\nalle\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                observed              county  \
# 2     While attending U.R.I in the Fall of 1974,I wo...   Washington County
# 5     My two children and I were returning from Altu...      Washita County
# 6     I was staying the night with a friends of mine...   Washington County
# 7     Well last year I was night fishing 9/2010 at A...  Westchester County
# 8     I grew up in Northwestern Nevada along the Cal...       Washoe County
# ...                                                 ...                 ...
# 5010  In October 2008 we went on a 4 wheeler trip to...       Harlan County
# ...

# %%
simplified_df.to_csv('cleaned_bigfoot.csv')

# %%
no_observed_df = simplified_df.drop(['observed'], axis=1, inplace=False)
no_observed_df
# Out:
#                   county         state  latitude  longitude        date
# 2      Washington County  Rhode Island  41.45000  -71.50000  1974-09-20
# 5         Washita County      Oklahoma  35.30110  -99.17020  1973-09-28
# 6      Washington County          Ohio  39.38745  -81.67339  1971-08-01
# 7     Westchester County      New York  41.29873  -73.73717  2010-09-01
# 8          Washoe County        Nevada  39.59200 -119.97500  1970-09-01
# ...                  ...           ...       ...        ...         ...
# 5010       Harlan County      Kentucky  36.89771  -83.16293  2008-10-15
# 5011       Harlan County      Kentucky  36.83193  -83.42429  2013-01-10
# 5012     Anderson County      Kentucky  37.95708  -84.97527  2005-01-09
# 5013     Anderson County      Kentucky  37.97699  -84.90234  2011-11-15
# 5015        Allen County      Kentucky  36.77200  -86.14250  2002-04-15
#
# [4012 rows x 5 columns]

# %%
no_observed_df.to_csv('cleaned_without_observed_column.csv')
