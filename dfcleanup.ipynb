# %%
import pandas as pd
import csv
import stringI0
df = pd.read_csv('haunted_places.csv', quotechar=None, quotechar='')
df
# Out:
#   File "C:\Users\marqu\AppData\Local\Temp/ipykernel_25744/4081717816.py", line 3
#     df = pd.read_csv('haunted_places.csv', quotechar=None, quotechar='')
#                                                            ^
# SyntaxError: keyword argument repeated: quotechar

# %%
# json_df = pd.read_json('https://query.data.world/s/mdx7cd63ly2te72r5xqn3u73za7etm')
# json_df
# f = open("haunted_places.json")
# data = json.load(f)
# Iterating through the json list
# for i in data:
#     print(i)

# Closing file
# f.close()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25744/1824351465.py in <module>
#       2 # json_df
#       3 f = open("haunted_places.json")
# ----> 4 data = json.load(f)
#       5 # Iterating through the json
#       6 # list
#
# ~\anaconda3\envs\PythonData\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# ~\anaconda3\envs\PythonData\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
# ...

# %%
df.dropna(how='any')
df
# Out:
#                 city        country  \
# 0                Ada  United States
# 1            Addison  United States
# 2             Adrian  United States
# 3             Adrian  United States
# 4             Albion  United States
# ...              ...            ...
# 10987    Westminster  United States
# 10988    Westminster  United States
# 10989    Wheat Ridge  United States
# 10990    Wheat Ridge  United States
# 10991  Woodland Park  United States
#
#                                              description  \
# 0      Ada witch - Sometimes you can see a misty blue...
# 1      A little girl was killed suddenly while waitin...
# 2      If you take Gorman Rd. west towards Sand Creek...
# 3      In the 1970's, one room, room 211, in the old ...
# 4      Kappa Delta Sorority - The Kappa Delta Sororit...
# ...                                                  ...
# 10987  at 12 midnight you can see a lady with two lit...
# 10988  Is haunted by the victims of a murder that hap...
# ...

# %%
df.drop(["city_longitude", "city_latitude"], axis=1, inplace=True)
# Out:
#                 city        country  \
# 0                Ada  United States
# 1            Addison  United States
# 2             Adrian  United States
# 3             Adrian  United States
# 4             Albion  United States
# ...              ...            ...
# 10987    Westminster  United States
# 10988    Westminster  United States
# 10989    Wheat Ridge  United States
# 10990    Wheat Ridge  United States
# 10991  Woodland Park  United States
#
#                                              description  \
# 0      Ada witch - Sometimes you can see a misty blue...
# 1      A little girl was killed suddenly while waitin...
# 2      If you take Gorman Rd. west towards Sand Creek...
# 3      In the 1970's, one room, room 211, in the old ...
# 4      Kappa Delta Sorority - The Kappa Delta Sororit...
# ...                                                  ...
# 10987  at 12 midnight you can see a lady with two lit...
# 10988  Is haunted by the victims of a murder that hap...
# ...

# %%
# df['description'].map(lambda x: x.replace('"', ''))
df.replace('"','', regex=True, inplace=True)
df
# Out:
#                 city        country  \
# 0                Ada  United States
# 1            Addison  United States
# 2             Adrian  United States
# 3             Adrian  United States
# 4             Albion  United States
# ...              ...            ...
# 10987    Westminster  United States
# 10988    Westminster  United States
# 10989    Wheat Ridge  United States
# 10990    Wheat Ridge  United States
# 10991  Woodland Park  United States
#
#                                              description  \
# 0      Ada witch - Sometimes you can see a misty blue...
# 1      A little girl was killed suddenly while waitin...
# 2      If you take Gorman Rd. west towards Sand Creek...
# 3      In the 1970's, one room, room 211, in the old ...
# 4      Kappa Delta Sorority - The Kappa Delta Sororit...
# ...                                                  ...
# 10987  at 12 midnight you can see a lady with two lit...
# 10988  Is haunted by the victims of a murder that hap...
# ...

# %%
df.to_csv('cleandf.csv')
